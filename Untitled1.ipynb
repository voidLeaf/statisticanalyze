# %%
d<-read.csv('data1_2.csv');
d<-data.frame(d)
y<-d[,2]
x1<-d[,4]
x2<-d[,5]
x3<-d[,6]
x4<-d[,7]
x5<-d[,8]
x6<-d[,9]
x7<-d[,10]
x8<-d[,11]
x9<-d[,12]
x10<-d[,13]
x11<-d[,14]
x12<-d[,15]
x13<-d[,16]
x14<-d[,17]
lm.sol<-lm(y~x1+x2+x3+x4+x5+x6+x7+x8+x9+x10+x11+x12+x13+x14)
summary(lm.sol)
lm.step1 <-step(lm.sol)
lm.drop1 <-drop1(lm.step1)
lm.drop1
summary(lm.drop1)
lm.sol2<-lm(y~x1+x2+x3+x4+x5+x6+x7+x8+x9+x10+x12+x14)
d
# Out:
# Call:
# lm(formula = y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 +
#     x10 + x11 + x12 + x13 + x14)
#
# Residuals:
#          1          2          3          4          5          6          7
#  1.027e-12 -9.741e-13 -1.419e+01  2.751e+01 -1.527e+01  9.584e+00 -1.559e+01
#          8          9         10         11         12         13         14
#  1.815e+01 -9.719e+00 -2.996e+00  4.438e+00 -4.539e+00 -7.684e+00 -5.421e+00
#         15         16         17         18         19         20
#  7.442e+00  1.954e+01 -3.271e+00  9.535e-01 -2.635e+01  1.741e+01
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.097e+03  1.459e+03   1.437   0.2102
# x1          -2.527e+03  2.054e+03  -1.230   0.2733
# x2           5.350e+01  4.174e+01   1.282   0.2561
# x3           1.199e+00  5.086e-01   2.358   0.0649 .
# x4           2.545e+03  2.060e+03   1.235   0.2716
# x5          -5.346e+01  4.152e+01  -1.288   0.2542
# ...

# %%
lm.step1 <-step(lm.sol)
# Out:
# Start:  AIC=133.49
# y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 + x10 + x11 +
#     x12 + x13 + x14
#
#        Df Sum of Sq    RSS    AIC
# - x11   1       0.7 3534.9 131.49
# - x13   1      27.4 3561.6 131.65
# - x14   1     212.5 3746.7 132.66
# <none>              3534.2 133.49
# - x9    1     769.8 4304.0 135.43
# - x12   1     952.5 4486.7 136.26
# - x1    1    1070.0 4604.2 136.78
# - x4    1    1078.5 4612.8 136.82
# - x2    1    1161.3 4695.5 137.17
# - x6    1    1168.0 4702.2 137.20
# - x5    1    1172.0 4706.2 137.22
# - x8    1    1248.1 4782.3 137.54
# - x10   1    2200.1 5734.3 141.17
# - x7    1    3320.2 6854.4 144.74
# - x3    1    3930.5 7464.7 146.44
#
# Step:  AIC=131.49
# y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 + x10 + x12 +
#     x13 + x14
#
#        Df Sum of Sq    RSS    AIC
# - x13   1      41.6 3576.5 129.73
# <none>              3534.9 131.49
# - x14   1     449.1 3984.0 131.89
# - x9    1     786.8 4321.7 133.51
# ...

# %%
summary(lm.sol2)
# Out:
# Call:
# lm(formula = y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 +
#     x10 + x12 + x14)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -25.271  -8.634  -0.158   6.618  27.643
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.003e+03  1.169e+03   1.713  0.13049
# x1          -2.746e+03  1.379e+03  -1.991  0.08677 .
# x2           5.787e+01  2.811e+01   2.058  0.07855 .
# x3           1.184e+00  4.287e-01   2.763  0.02798 *
# x4           2.763e+03  1.385e+03   1.995  0.08623 .
# x5          -5.782e+01  2.792e+01  -2.071  0.07710 .
# x6          -5.904e+01  2.852e+01  -2.070  0.07718 .
# x7          -2.063e+00  8.135e-01  -2.537  0.03886 *
# x8          -5.166e-01  1.074e-01  -4.812  0.00194 **
# x9          -6.688e-01  5.181e-01  -1.291  0.23776
# x10         -2.665e+00  1.277e+00  -2.087  0.07535 .
# x12         -2.397e-01  1.414e-01  -1.695  0.13389
# x14         -4.368e-06  2.099e-06  -2.081  0.07602 .
# ---
# ...

# %%
step(lm.sol2)
# Out:
# Start:  AIC=129.73
# y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 + x10 + x12 +
#     x14
#
#        Df Sum of Sq     RSS    AIC
# <none>               3576.5 129.73
# - x9    1     851.3  4427.9 132.00
# - x12   1    1468.0  5044.5 134.61
# - x1    1    2025.3  5601.8 136.70
# - x4    1    2034.0  5610.5 136.73
# - x2    1    2164.8  5741.3 137.19
# - x6    1    2190.1  5766.6 137.28
# - x5    1    2191.5  5768.0 137.29
# - x14   1    2211.8  5788.3 137.36
# - x10   1    2224.5  5801.1 137.40
# - x7    1    3287.5  6864.0 140.77
# - x3    1    3899.9  7476.4 142.48
# - x8    1   11831.1 15407.6 156.94
# Call:
# lm(formula = y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 +
#     x10 + x12 + x14)
#
# Coefficients:
# (Intercept)           x1           x2           x3           x4           x5
#   2.003e+03   -2.746e+03    5.787e+01    1.184e+00    2.763e+03   -5.782e+01
#          x6           x7           x8           x9          x10          x12
# ...

# %%
name = data.frame(t(summary(d[,2:18])))[1:17,1]
min = data.frame(t(summary(d[,2:18])))[1:17,3]
x1 =  data.frame(t(summary(d[,2:18])))[18:34,3]
x2 =  data.frame(t(summary(d[,2:18])))[35:51,3]
x3 =  data.frame(t(summary(d[,2:18])))[52:68,3]
x4 =  data.frame(t(summary(d[,2:18])))[69:85,3]
x5 =  data.frame(t(summary(d[,2:18])))[86:102,3]
data.frame(name,min,x2,x3,x5)
# Out:
#                                name                 min                  x2
# 1        地方财政一般预算收入.亿元.    Min.   : 115.3      Median : 831.9
# 2                地区生产总值.亿元.     Min.   : 1508       Median : 6501
# 3              第一产业增加值.亿元.    Min.   : 72.16      Median : 88.02
# 4              第二产业增加值.亿元.    Min.   : 645.8      Median :1940.0
# 5              第三产业增加值.亿元.   Min.   :  789.7     Median : 4473.3
# 6            农林牧渔业增加值.亿元.    Min.   : 72.16      Median : 88.02
# 7                  工业增加值.亿元.    Min.   : 527.8      Median :1630.9
# 8                建筑业增加值.亿元.     Min.   :118.0       Median :309.2
# 9                金融业增加值.亿元.    Min.   : 152.9      Median : 777.0
# 10             房地产业增加值.亿元.   Min.   :  22.45     Median : 464.92
# 11             其他行业增加值.亿元.    Min.   : 289.1      Median :2032.5
# 12               年末常住人口.万人.      Min.   :1248        Median :1516
# 13         全社会固定资产投资.亿元.    Min.   : 841.5      Median :2677.7
# ...

# %%
summary(lm.sol)
# Out:
# Call:
# lm(formula = y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 +
#     x10 + x11 + x12 + x13 + x14)
#
# Residuals:
#          1          2          3          4          5          6          7
#  1.027e-12 -9.741e-13 -1.419e+01  2.751e+01 -1.527e+01  9.584e+00 -1.559e+01
#          8          9         10         11         12         13         14
#  1.815e+01 -9.719e+00 -2.996e+00  4.438e+00 -4.539e+00 -7.684e+00 -5.421e+00
#         15         16         17         18         19         20
#  7.442e+00  1.954e+01 -3.271e+00  9.535e-01 -2.635e+01  1.741e+01
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.097e+03  1.459e+03   1.437   0.2102
# x1          -2.527e+03  2.054e+03  -1.230   0.2733
# x2           5.350e+01  4.174e+01   1.282   0.2561
# x3           1.199e+00  5.086e-01   2.358   0.0649 .
# x4           2.545e+03  2.060e+03   1.235   0.2716
# x5          -5.346e+01  4.152e+01  -1.288   0.2542
# ...

# %%
plot(lm.sol)
# Out:
# Warning message:
# “not plotting observations with leverage one:
#   1, 2”
# Plot with title “”
# Warning message:
# “not plotting observations with leverage one:
#   1, 2”
# Plot with title “”
# Warning message in sqrt(crit * p * (1 - hh)/hh):
# “产生了NaNs”Warning message in sqrt(crit * p * (1 - hh)/hh):
# “产生了NaNs”
# Plot with title “”
# Plot with title “”

# %%
install.packages('bptest')

# %%
install.packages('normtest')

# %%
install.packages('car')
# Out:
# also installing the dependencies ‘minqa’, ‘nloptr’, ‘nlme’, ‘lme4’, ‘SparseM’, ‘mgcv’, ‘pbkrtest’, ‘quantreg’
#
# Warning message in install.packages("car"):
# “installation of package ‘minqa’ had non-zero exit status”Warning message in install.packages("car"):
# “installation of package ‘nloptr’ had non-zero exit status”Warning message in install.packages("car"):
# “installation of package ‘nlme’ had non-zero exit status”Warning message in install.packages("car"):
# “installation of package ‘SparseM’ had non-zero exit status”Warning message in install.packages("car"):
# “installation of package ‘lme4’ had non-zero exit status”Warning message in install.packages("car"):
# “installation of package ‘mgcv’ had non-zero exit status”Warning message in install.packages("car"):
# “installation of package ‘quantreg’ had non-zero exit status”Warning message in install.packages("car"):
# “installation of package ‘pbkrtest’ had non-zero exit status”Warning message in install.packages("car"):
# ...

# %%
library('lmtest')
# Out:
# Error in library("lmtest"): there is no package called ‘lmtest’
# Traceback:
#
# 1. library("lmtest")
# 2. stop(txt, domain = NA)

# %%
library('normtest')
install.packages('car')

# %%
res<-residuals(lm.sol)
jb.norm.test(res)
# Out:
# 	Jarque-Bera test for normality
#
# data:  res
# JB = 0.35694, p-value = 0.809

# %%
lm.sol2<- lm(y~x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 + x10 + x12 + x14)
summary(lm.sol2)
lm.step<-drop1(lm.sol2)
# Out:
# Call:
# lm(formula = y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 +
#     x10 + x12 + x14)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -25.271  -8.634  -0.158   6.618  27.643
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.003e+03  1.169e+03   1.713  0.13049
# x1          -2.746e+03  1.379e+03  -1.991  0.08677 .
# x2           5.787e+01  2.811e+01   2.058  0.07855 .
# x3           1.184e+00  4.287e-01   2.763  0.02798 *
# x4           2.763e+03  1.385e+03   1.995  0.08623 .
# x5          -5.782e+01  2.792e+01  -2.071  0.07710 .
# x6          -5.904e+01  2.852e+01  -2.070  0.07718 .
# x7          -2.063e+00  8.135e-01  -2.537  0.03886 *
# x8          -5.166e-01  1.074e-01  -4.812  0.00194 **
# x9          -6.688e-01  5.181e-01  -1.291  0.23776
# x10         -2.665e+00  1.277e+00  -2.087  0.07535 .
# x12         -2.397e-01  1.414e-01  -1.695  0.13389
# x14         -4.368e-06  2.099e-06  -2.081  0.07602 .
# ---
# ...

# %%
summary(lm.step)
# Out:
#        Df      Sum of Sq            RSS             AIC
#  Min.   :1   Min.   :  851.3   Min.   : 3577   Min.   :129.7
#  1st Qu.:1   1st Qu.: 2031.8   1st Qu.: 5602   1st Qu.:136.7
#  Median :1   Median : 2190.8   Median : 5767   Median :137.3
#  Mean   :1   Mean   : 3031.6   Mean   : 6375   Mean   :138.2
#  3rd Qu.:1   3rd Qu.: 2490.3   3rd Qu.: 5801   3rd Qu.:137.4
#  Max.   :1   Max.   :11831.1   Max.   :15408   Max.   :156.9
#  NA's   :1   NA's   :1

# %%
plot(lm.sol2)
# Out:
# Warning message:
# “not plotting observations with leverage one:
#   1, 2”
# Plot with title “”
# Warning message:
# “not plotting observations with leverage one:
#   1, 2”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
lm.sol2<- lm(y~x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 + x10 + x12 + x14)
step(lm.sol2)
# Out:
# Start:  AIC=129.73
# y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 + x10 + x12 +
#     x14
#
#        Df Sum of Sq     RSS    AIC
# <none>               3576.5 129.73
# - x9    1     851.3  4427.9 132.00
# - x12   1    1468.0  5044.5 134.61
# - x1    1    2025.3  5601.8 136.70
# - x4    1    2034.0  5610.5 136.73
# - x2    1    2164.8  5741.3 137.19
# - x6    1    2190.1  5766.6 137.28
# - x5    1    2191.5  5768.0 137.29
# - x14   1    2211.8  5788.3 137.36
# - x10   1    2224.5  5801.1 137.40
# - x7    1    3287.5  6864.0 140.77
# - x3    1    3899.9  7476.4 142.48
# - x8    1   11831.1 15407.6 156.94
# Call:
# lm(formula = y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 +
#     x10 + x12 + x14)
#
# Coefficients:
# (Intercept)           x1           x2           x3           x4           x5
#   2.003e+03   -2.746e+03    5.787e+01    1.184e+00    2.763e+03   -5.782e+01
#          x6           x7           x8           x9          x10          x12
# ...

# %%
lm.sol2<- lm(y~x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8  + x10 + x12 + x14)
step(lm.sol2)
# Out:
# Start:  AIC=132
# y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x10 + x12 + x14
#
#        Df Sum of Sq     RSS    AIC
# <none>               4427.9 132.00
# - x12   1     617.1  5044.9 132.61
# - x14   1    1461.5  5889.4 135.70
# - x1    1    1676.3  6104.1 136.42
# - x4    1    1691.9  6119.8 136.47
# - x6    1    1870.3  6298.2 137.05
# - x2    1    1937.7  6365.5 137.26
# - x5    1    1984.6  6412.5 137.41
# - x10   1    3120.9  7548.8 140.67
# - x7    1    5411.4  9839.3 145.97
# - x8    1   11465.8 15893.6 155.56
# - x3    1   22690.5 27118.4 166.25
# Call:
# lm(formula = y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x10 +
#     x12 + x14)
#
# Coefficients:
# (Intercept)           x1           x2           x3           x4           x5
#   7.030e+02   -1.175e+03    2.589e+01    6.454e-01    1.186e+03   -2.609e+01
#          x6           x7           x8          x10          x12          x14
#  -2.709e+01   -1.110e+00   -5.074e-01   -1.125e+00   -1.027e-01   -3.211e-06

# %%
lm.sol2<- lm(y~x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x10  + x14)
step(lm.sol2)
# Out:
# Start:  AIC=132.61
# y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x10 + x14
#
#        Df Sum of Sq     RSS    AIC
# <none>               5044.9 132.61
# - x14   1     845.1  5890.0 133.71
# - x1    1    1150.0  6194.9 134.72
# - x4    1    1165.6  6210.5 134.76
# - x6    1    1324.5  6369.4 135.27
# - x2    1    1394.1  6439.0 135.49
# - x5    1    1440.7  6485.7 135.63
# - x7    1    4988.6 10033.6 144.36
# - x10   1    5640.1 10685.1 145.62
# - x8    1   12355.5 17400.5 155.37
# - x3    1   25828.9 30873.9 166.84
# Call:
# lm(formula = y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x10 +
#     x14)
#
# Coefficients:
# (Intercept)           x1           x2           x3           x4           x5
#   9.368e+02   -8.949e+02    2.027e+01    5.907e-01    9.061e+02   -2.056e+01
#          x6           x7           x8          x10          x14
#  -2.094e+01   -9.222e-01   -5.224e-01   -1.350e+00   -1.823e-06

# %%
lm.sol2<- lm(y~x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x10)
step(lm.sol2)
# Out:
# Start:  AIC=133.71
# y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x10
#
#        Df Sum of Sq   RSS    AIC
# <none>               5890 133.71
# - x1    1    1172.7  7063 135.34
# - x4    1    1190.4  7080 135.39
# - x6    1    1273.0  7163 135.62
# - x2    1    1405.1  7295 135.98
# - x5    1    1447.8  7338 136.10
# - x7    1    4482.7 10373 143.02
# - x10   1    6182.1 12072 146.06
# - x8    1   13643.0 19533 155.68
# - x3    1   27482.6 33373 166.40
# Call:
# lm(formula = y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x10)
#
# Coefficients:
# (Intercept)           x1           x2           x3           x4           x5
#    886.1803    -903.6619      20.3535       0.5418     915.5842     -20.6118
#          x6           x7           x8          x10
#    -20.5231      -0.8637      -0.5428      -1.4053

# %%
lm.sol2<- lm(y~ x2 + x3 + x4 + x5 + x6 + x7 + x8 + x10)
step(lm.sol2)
# Out:
# Start:  AIC=135.34
# y ~ x2 + x3 + x4 + x5 + x6 + x7 + x8 + x10
#
#        Df Sum of Sq   RSS    AIC
# - x6    1       432  7495 134.52
# <none>               7063 135.34
# - x7    1      4251 11313 142.76
# - x4    1      6882 13945 146.94
# - x10   1      8437 15500 149.06
# - x2    1      9607 16669 150.51
# - x5    1     13198 20261 154.41
# - x8    1     13580 20643 154.79
# - x3    1     32389 39452 167.74
#
# Step:  AIC=134.52
# y ~ x2 + x3 + x4 + x5 + x7 + x8 + x10
#
#        Df Sum of Sq   RSS    AIC
# <none>               7495 134.52
# - x7    1      6266 13761 144.68
# - x4    1      6460 13954 144.96
# - x2    1      9742 17237 149.18
# - x10   1     12761 20256 152.41
# - x8    1     13190 20685 152.83
# - x5    1     13560 21054 153.18
# - x3    1     32359 39854 165.94
# Call:
# lm(formula = y ~ x2 + x3 + x4 + x5 + x7 + x8 + x10)
#
# Coefficients:
# (Intercept)           x2           x3           x4           x5           x7
# ...

# %%
lm.sol2<- lm(y~ x2 + x3 + x4 + x5  + x7 + x8 + x10)
step(lm.sol2)
# Out:
# Start:  AIC=134.52
# y ~ x2 + x3 + x4 + x5 + x7 + x8 + x10
#
#        Df Sum of Sq   RSS    AIC
# <none>               7495 134.52
# - x7    1      6266 13761 144.68
# - x4    1      6460 13954 144.96
# - x2    1      9742 17237 149.18
# - x10   1     12761 20256 152.41
# - x8    1     13190 20685 152.83
# - x5    1     13560 21054 153.18
# - x3    1     32359 39854 165.94
# Call:
# lm(formula = y ~ x2 + x3 + x4 + x5 + x7 + x8 + x10)
#
# Coefficients:
# (Intercept)           x2           x3           x4           x5           x7
#   1512.6048       1.6077       0.4638       6.4872      -1.9200      -0.5767
#          x8          x10
#     -0.5191      -1.7354

# %%
lm.sol2<- lm(y~ x2 + x3 + x4 + x5  + x7 + x8 + x10)
summary(lm.sol2)
# Out:
# Call:
# lm(formula = y ~ x2 + x3 + x4 + x5 + x7 + x8 + x10)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -33.128 -18.006   2.007  15.255  36.386
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1512.60481  471.13758   3.211 0.007485 **
# x2             1.60768    0.40705   3.950 0.001929 **
# x3             0.46376    0.06443   7.198 1.09e-05 ***
# x4             6.48722    2.01709   3.216 0.007407 **
# x5            -1.91999    0.41205  -4.660 0.000551 ***
# x7            -0.57672    0.18207  -3.168 0.008107 **
# x8            -0.51914    0.11296  -4.596 0.000616 ***
# x10           -1.73536    0.38391  -4.520 0.000702 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 24.99 on 12 degrees of freedom
# Multiple R-squared:  0.9998,	Adjusted R-squared:  0.9996
# F-statistic:  7124 on 7 and 12 DF,  p-value: < 2.2e-16
